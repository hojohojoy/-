# %%
from matplotlib import pyplot as plt

plt.rcParams ['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif']=['SimHei']
plt.style.use('ggplot')

x=[0,1]
y1=[0.4245880,0.3341708]
y2=[-0.022840,-0.027912]
y3=[-0.054217,-0.054217]
y4=[0.0735938,0.0855100]
y5=[-0.286645,-0.276272]
plt.figure(figsize=(1,5),dpi=1000) #设置图片大小和像素
#plt.plot(x,y1,label='计算文本情感值方法：按频率',color='green') #设置折线颜色和标签
plt.plot(x,y2,label='文本平均情感值',color='blue')
plt.plot(x,y3,label='词典平均情感值',color='red')
plt.plot(x,y4,label='积极词平均情感值',color='orange')
plt.plot(x,y5,label='消极词平均情感值',color='yellow')
plt.xticks(range(2),labels=['疫情前','疫情后']) #x轴坐标轴
plt.ylim((-0.3, 0.1))#y轴坐标轴
plt.ylabel('平均每词带有的情感值')
plt.legend(fontsize=4,loc='center right')#添加图例
#plt.text(0,0.4245880,0.4245880,ha='left',va='bottom',fontsize=4)
#plt.text(1,0.3341708,0.3341708,ha='left',va='bottom',fontsize=4)
plt.text(0,-0.022840,-0.022840,ha='left',va='bottom',fontsize=4)
plt.text(1,-0.027912,-0.027912,ha='left',va='bottom',fontsize=4)
plt.text(0,-0.054217,-0.054217,ha='left',va='bottom',fontsize=4)
plt.text(1,-0.054217,-0.054217,ha='left',va='bottom',fontsize=4)
plt.text(0,0.0735938,0.0735938,ha='left',va='bottom',fontsize=4)
plt.text(1,0.0855100,0.0855100,ha='left',va='bottom',fontsize=4)
plt.text(0,-0.286645,-0.286645,ha='left',va='bottom',fontsize=4)
plt.text(1,-0.276272,-0.276272,ha='left',va='bottom',fontsize=4)
plt.show()
